# %%
from qiskit import QuantumCircuit, QuantumRegister, AncillaRegister, ClassicalRegister

qr = QuantumRegister(2,'q')
ar = AncillaRegister(1)
# ar = QuantumRegister(1,'a')
cr = ClassicalRegister(2,'c')

qc = QuantumCircuit(qr,ar,cr)
qc.h(0)
qc.ry(1.1,2)
qc.cx(2,0)
qc.cx(2,1)

qc.measure([0,1],[0,1])
qc.draw('mpl')

# %%
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
from qiskit import transpile

sim = AerSimulator()
qct = transpile(qc,sim)
job = sim.run(qct,shots=100)
result = job.result()
counts= result.get_counts()

# %%
from qiskit.visualization import plot_histogram

plot_histogram(counts)

# %%
from qiskit import transpile, generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2, SamplerOptions

service = QiskitRuntimeService()

backend = service.least_busy(simulator=False, operational=True)
print(backend.name)
# Out:
# ibm_torino

# %%
options = SamplerOptions(default_shots=100, max_execution_time=60)
sampler = SamplerV2(mode = backend,options = options)

# %%
pm = generate_preset_pass_manager(backend=backend, optimization_level=1,seed_transpiler=145)
qc_isa = pm.run(qc)
qc_isa.draw('mpl')

# %%
job = sampler.run([qc_isa])

# %%
results2 = job.result()[0]
counts2 = results2.join_data().get_counts()
# Out:
# ---------------------------------------------------------------------------
# RuntimeJobFailureError                    Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 results2 = job.result()[0]
#       2 counts2 = results2.join_data().get_counts()
#
# File ~/Documents/qiskit2/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:138, in RuntimeJobV2.result(self, timeout, decoder)
#     136     if self._reason_code == 1305:
#     137         raise RuntimeJobMaxTimeoutError(error_message)
# --> 138     raise RuntimeJobFailureError(f"Unable to retrieve job result. {error_message}")
#     139 if self._status == "CANCELLED":
#     140     raise RuntimeInvalidStateError(
#     141         "Unable to retrieve result for job {}. " "Job was cancelled.".format(self.job_id())
#     142     )
#
# RuntimeJobFailureError: "Unable to retrieve job result. TypeError: unsupported operand type(s) for -: 'NoneType' and 'int"

# %%
plot_histogram(counts2)
